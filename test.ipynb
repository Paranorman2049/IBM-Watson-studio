# %% [markdown]
# # Demo notebook
# ## First one in Watson

# %%
import numpy as np
import seaborn as sns

# %%
x = np.array([1,2,3,4,4,5,6,7,6,8,8,9,8,8,9,5,7,3,3,2,4,1,5,6,7])
print(x)
# Out:
# [1 2 3 4 4 5 6 7 6 8 8 9 8 8 9 5 7 3 3 2 4 1 5 6 7]

# %%
sns.distplot(x)
